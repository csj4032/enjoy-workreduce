# %%
import random
from datetime import datetime

import mysql.connector
from faker import Faker
from pydeequ.analyzers import *
from pydeequ.checks import Check, CheckLevel
from pydeequ.verification import VerificationSuite
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from pyspark.sql.types import StructType, StructField, IntegerType, StringType
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>00g2gjjquhipj12q</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="https://j-00g2gjjquhipj12q.dashboard.emr-serverless.ap-northeast-2.amazonaws.com/?authToken=eDAxjVnjPv3JzhGEsTxWBrzYitJsFY3NnGru-Q0Yv3PW04vE3CORHU005BzzUBmrHZq0l4oDkn8WjASNrWl8u_FpA98_hdBEqK1dt-h0qY4v0R94jRE6bLukNFmRcQgmkT0HqL-ASiT_3Fe_Z2WfLm1Ve9BDcy4zQVjZhsyfuRxHgKkon61a0WexkgAeYaH673U4sgV3ofsfimVHtBe7Vzvfj3pxTdwgoCDtX0g7Zh-ClkLCQoSckaikUMG_yYevP0xBX_Oz2tVySx5XZlIhT5XjJwRPHa1a9wyWQP56KpkEOyrJqr3zvlbpog_bxcBF5CowEiP_iEuC-hW0Pm8cTNIT48wLP4iHuIumV7o7mL57_lMlVHzg83cMcK1vm7mgMGT61WBl7in_CCnHZq_vBtRkwJVb-nypwwTI3l2lEDZtKK-ceOfVvqDtB1PE1vF-W-QNO6lDiCH1OjSnKJ4wWgcWnNXowsBK4SA9cxUxaNQ_ssAlG1pMJ5Jjt2wCh-Xo7vAXzB1Ym_P34riqP65yx1U1uB3C9IEPEOBy9ZO2thFabEWIkG8q6a69vVdg-Xaav_pS86xFoPU5Mvt_EKcEpR-0sKljGM-VPkcH5eZ1Fb5XVTo10_HAR8YXBbaTIjfcReGjnN0RBqmkD_kTI5NbHuFzncGtvKJn0I8MLDedxBcNs2BZH9BT-AK2JO9wRZhj0lyfPc_tLFK-r9Bjpg144HFPMnhMpibdSzpF56bR8pzXVUd8JfayR0OaLCFQgmj4PFx2O_RXE9d-43nyIcDzHr1JT0SKug3ApftdRZlSeHbvb8xt8lpHZxhvOHCyDG1_dCn8AZNjbo6csP7D0q7RpbNxi6S5....">Link</a></td><td><a target="_blank" href="https://j-00g2gjjquhipj12q.dashboard.emr-serverless.ap-northeast-2.amazonaws.com/logs/SPARK_DRIVER/stderr.gz?authToken=eDAxxaDPSEgg0xBk4-rQLTyfLhrrqNGN50s95yQMGUY7AMkvHKy0DqA-I0agehMinC9P0NIaezMkGmlOY-tVzX-6I87FhAkIFJCvWmfDy1ZDA7ucPUjfSWE-i-cYXeEgXlKAGEN1PQxatXCSp7yHE7NGYKXMx2ndoqdMkdl5VQp7F4wCf27-XVdRoVyKhtrod-KPgL8B_2ERzh7QraSe5i7swO2z5QI3Ydu8xNJVMYRhG8fLwJg52o_qk90lqa5BggXJMI-M1jFeuUZ8AbQRJoVKsujOv5dxs9ASySYFdYOWeK6pQ5Qu8YxZvwQ7YtyTNEIzy0c0qy62mDenUdKdYqgeMRjAixAnjHD8OF2knoCZEHD1ndOYH9L1BzApe9F-FfU79iUsq5gM-G9YySbew9jpAlcUoJQiDZX1YdakBnM1fF8w_M-oObo8DLEmqJElGpP_cC4tb2qmONWVlpuDfhpFMwcU3QqsB3OrheL5xRHQVgxUnZuqYQlcNpISFNu-hSBAPtBV12p-KgnCkFMzBb4PUWSDGDNHsPMqjLYCmQ2NIzvF-N4v9u3-MePjtGvZN1_j00YXhkm24Z4tGMv6eSBDhQ27tInNmGZqKRcb7gyKTN-dpHrc72t4pTbq6XZjydBiLir_D2CuxttbCAoihd8-zE0BQ_O6Gh3SfX75LCNT2KdwaOMsBp8mVh6dqYn-EqXJ8b_AboDwzl6pou1dTMgmPwUzbjoH8Qbo5mzSo-UHFZTagQipwoWgnRu8G-iq-XHIoLrQCCag7D3d7M6KN2ttHNQYSWF2j3lQt5FfbgHEflFDDHPJEuu_PayuDPc5qJ1Tgp_tO-pf-eGrsHrE3BXKFQ....">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
Faker.seed(42)
fake = Faker(['ko_KR', 'en_US'])
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
data = [{
    "id": i + 1,
    "name": fake.name(),
    "age": fake.random_int(min=20, max=65),
    "weigh": fake.random_int(min=10, max=250),
    "height": fake.random_int(min=10, max=250),
    "gender": random.choice(['남성', '여성']),
    "address": fake.address(),
    "job": fake.job(),
    "email": fake.email()
} for i in range(100)]

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("weight", IntegerType(), True),
    StructField("height", IntegerType(), True),
    StructField("gender", StringType(), True),
    StructField("address", StringType(), True),
    StructField("job", StringType(), True),
    StructField("email", StringType(), True)
])
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
df = spark.createDataFrame(data=data, schema=schema)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
check = (
    Check(spark, CheckLevel.Error, "Basic data checks")
    .hasSize(lambda x: x == 100)
    .isComplete("id")
    .isComplete("name")
    .isComplete("age")
    .isComplete("gender")
    .isComplete("email")
)

result = (VerificationSuite(spark).onData(df).addCheck(check).run())
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
analysis_runner = AnalysisRunner(spark)
analysis_result = (
    analysis_runner.onData(df)
    .addAnalyzer(Size())
    .addAnalyzer(Completeness("id"))
    .addAnalyzer(Completeness("name"))
    .addAnalyzer(Completeness("age"))
    .addAnalyzer(Correlation("height", "weight"))
    .addAnalyzer(Completeness("gender"))
    .addAnalyzer(Completeness("address"))
    .addAnalyzer(Completeness("job"))
    .addAnalyzer(Completeness("email"))
    .run())
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
result_df = AnalyzerContext.successMetricsAsDataFrame(spark, analysis_result) \
    .withColumn("run_name", lit("daily_batch")) \
    .withColumn("run_id", lit(f"daily_batch_{datetime.now().strftime('%Y%m%d%H%M%S')}")) \
    .withColumn("logical_datetime", lit(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"))
result_df.printSchema()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- entity: string (nullable = true)
#  |-- instance: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- value: double (nullable = false)
#  |-- run_name: string (nullable = false)
#  |-- run_id: string (nullable = false)
#  |-- logical_datetime: string (nullable = false)
#
# /usr/lib/spark/python/lib/pyspark.zip/pyspark/sql/dataframe.py:147: UserWarning: DataFrame constructor is internal. Do not directly use it.
