# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .appName("PyDeequ Example") \
    .master("spark://spark-master:7077") \
    .config("spark.sql.shuffle.partitions", "1") \
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .config("spark.hadoop.fs.s3a.access.key", "mmix") \
    .config("spark.hadoop.fs.s3a.secret.key", "mmixmmix") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions") \
    .config("spark.sql.catalog.hadoop", "org.apache.iceberg.spark.SparkCatalog") \
    .config("spark.sql.catalog.hadoop.type", "hadoop") \
    .config("spark.sql.catalog.hadoop.warehouse", "s3a://mmix-prod-dataengineer-datalakehouse/streaming/") \
    .getOrCreate()
# Out:
# 26/01/19 01:10:35 WARN Utils: Your hostname, genius.local resolves to a loopback address: 127.0.0.1; using 192.168.45.141 instead (on interface en0)
# 26/01/19 01:10:35 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/19 01:10:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/19 01:10:35 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/01/19 01:10:35 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 26/01/19 01:10:35 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 26/01/19 01:10:35 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.

# %%
event_log = spark.read.parquet("s3a://mmix-prod-dataengineer-datalakehouse/messaging/topics/debezium/debezium.mysql.source.mmix.event_log/year=2026/month=01/day=18/hour=16/*.snappy.parquet")
event_log.show()
# Out:
# 26/01/19 01:10:36 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 26/01/19 01:10:49 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors
# 26/01/19 01:10:52 WARN TaskSchedulerImpl: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# +--------+--------------------+-------------+------------------+-----------+---------+-------+--------------------+
# |event_id|          event_uuid|   event_time|        event_type|entity_type|entity_id|user_id|             payload|
# +--------+--------------------+-------------+------------------+-----------+---------+-------+--------------------+
# ...
