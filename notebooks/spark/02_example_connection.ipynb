# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("PyDeequ Example") \
    .master("spark://spark-master.mmix.io:7077") \
    .config("spark.sql.shuffle.partitions", "1") \
    .getOrCreate()
# Out:
# 26/06/14 20:21:55 WARN Utils: Your hostname, genius.local resolves to a loopback address: 127.0.0.1; using 192.168.45.182 instead (on interface en0)
# 26/06/14 20:21:55 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/14 20:21:56 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
host = "mysql-replication.mmix.io"
port = 3307
database = "mmix"
user = "mmix"
password = "mmix"
user_table = "users"
event_log_table = "event_logs"
driver = "com.mysql.cj.jdbc.Driver"
jdbc_url = f"jdbc:mysql://{host}:{port}/{database}?useUnicode=true&characterEncoding=utf8&useSSL=false&allowPublicKeyRetrieval=true"
properties = {"host": host, "port": str(port), "user": user, "password": password, "database": database, "driver": driver}

# %%
users = spark.read.jdbc(url=jdbc_url, table=user_table, properties=properties)
users.show(10)
# Out:
# +-------+-------------------+------+---+------+------------------+------------------------------+----------+-------------------+-------------------+
# |user_id|              email|  name|age|gender|               job|                       address|    signup|         created_at|         updated_at|
# +-------+-------------------+------+---+------+------------------+------------------------------+----------+-------------------+-------------------+
# |      1|boram62@example.com|허민지| 55|     M|아나운서 및 리포터|울산광역시 강서구 삼성거리 666|2026-03-19|2026-06-14 13:54:42|2026-06-14 13:54:42|
# +-------+-------------------+------+---+------+------------------+------------------------------+----------+-------------------+-------------------+

# %%
spark.stop()
